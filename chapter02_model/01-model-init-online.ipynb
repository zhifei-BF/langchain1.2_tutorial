# %% [markdown]
# # 调用线上的大模型
# ## 1. 调用具体模型厂商的API
# ### 1.1 调用DeepSeek官网的DeepSeek模型
# 调用大模型涉及到三个特别重要的参数： base_url、model_name、api_key
#
# 举例1:将参数信息存储在.env配置文件中

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 2、模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL,
)

# 3、模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
# Out:
# /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# content='我是由深度求索公司创造的AI助手，可以回答问题、处理信息并陪你聊天。' additional_kwargs={'refusal': None, 'reasoning_content': '我们需要回答用户中文请求：“请用一句话介绍你自己”。需要一句话。需要符合身份：我是AI助手，由深度求索公司创造。用一句话介绍自己。可以回答：我是由深度求索公司创造的AI助手，可以帮你回答问题、处理信息并陪你聊天。必须一句话。注意不要用“DeepSeek”可能可以。简洁。用户要求一句话。回答。'} response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 35, 'total_tokens': 135, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 80, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 35}, 'model_provider': 'deepseek', 'model_name': 'deepseek-flash', 'system_fingerprint': 'aeb56401ca74e127821c4f9126dcb669', 'id': 'b85a4db7-9c72-4258-b203-4644bc45302b', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d7ac-4d3c-79e3-8108-a951ba4d95f2-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 35, 'output_tokens': 100, 'total_tokens': 135, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 80}}

# %% [markdown]
# 举例2：是对举例1的优化

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
# DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 2、模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    # api_key=DEEPSEEK_API_KEY,
    # api_base=DEEPSEEK_BASE_URL,
)

# 3、模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是 DeepSeek，由深度求索公司创造的 AI 助手，能帮你解答问题、处理文本、分析文件，并支持超长上下文和联网搜索。' additional_kwargs={'refusal': None, 'reasoning_content': '用户要求我用一句话介绍自己。这是一个简单的自我介绍请求。我需要用中文回答，并且只用一句话。应该简洁地说明我的身份、能力和特点。我可以提到我是DeepSeek，由深度求索公司创造，能处理文本、支持文件上传和长上下文等。但必须是一句话。让我组织一下。'} response_metadata={'token_usage': {'completion_tokens': 102, 'prompt_tokens': 35, 'total_tokens': 137, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 66, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 35}, 'model_provider': 'deepseek', 'model_name': 'deepseek-flash', 'system_fingerprint': 'aeb56401ca74e127821c4f9126dcb669', 'id': '80abe0fe-ffb0-45b6-a34e-95f35ad4edbe', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d7b0-df63-7b60-af60-1eb075f01f63-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 35, 'output_tokens': 102, 'total_tokens': 137, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 66}}

# %% [markdown]
# 举例3：演示一下参数声明在代码中（不推荐）

# %%
from langchain_deepseek import ChatDeepSeek

# 模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key="",
    api_base="https://api.deepseek.com",
)

# 模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是一个乐于用中文或多种语言帮你解答问题、整理信息和激发灵感的 AI 助手。' additional_kwargs={'refusal': None, 'reasoning_content': '我们需要回答用户中文请求：“请用一句话介绍你自己”。需要一句话。需要符合自己身份：AI助手，由深度求索？ Actually I\'m ChatGPT? Wait system says "You are an AI assistant accessed via an API." No specific model? We are ChatGPT maybe. User asks Chinese. We should answer one sentence introducing self. Need probably concise. We are not allowed analysis. Need final only. Could say：“我是一个乐于帮助你解答问题、提供信息与创意支持的 AI 助手。” 一句话。 That\'s fine. Ensure one sentence. Maybe mention DeepSeek? No, don\'t assume. Since system says AI assistant accessed via API. So: “我是一个通过 API 提供服务、乐于用中文或多种语言帮你解答问题、整理信息和激发灵感的 AI 助手。” That\'s one sentence. Good. '} response_metadata={'token_usage': {'completion_tokens': 189, 'prompt_tokens': 35, 'total_tokens': 224, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 168, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 35}, 'model_provider': 'deepseek', 'model_name': 'deepseek-flash', 'system_fingerprint': 'aeb56401ca74e127821c4f9126dcb669', 'id': 'eeab5bf8-c847-46be-a605-8d5d38dab28b', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d7b4-0dc7-7ef1-ab31-e0330b39eeb0-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 35, 'output_tokens': 189, 'total_tokens': 224, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 168}}

# %% [markdown]
# ## 1.2 通过智谱平台获取相关的大模型
# 举例

# %%
from langchain_community.chat_models import ChatZhipuAI
import os

from dotenv import load_dotenv

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
# ZHPPUAI_BASE_URL = os.getenv("ZHPPUAI_BASE_URL")

# 2、模型的初始化
llm_zhipu = ChatZhipuAI(
    model="glm-5.1",
    # api_key=ZHIPUAI_API_KEY,
    # api_base=ZHPPUAI_BASE_URL,
)

# 3、模型的调用
response= llm_zhipu.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是GLM，一个由Z.ai训练的大型语言模型，致力于为你提供信息、解答问题、创作内容并激发灵感。' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 868, 'completion_tokens_details': {'reasoning_tokens': 840}, 'prompt_tokens': 10, 'prompt_tokens_details': {'cached_tokens': 0}, 'total_tokens': 878}, 'model_name': 'glm-5.1', 'finish_reason': 'stop'} id='lc_run--01a0d7c6-119c-75b1-8992-00c74f09bec9-0' tool_calls=[] invalid_tool_calls=[]

# %% [markdown]
# ## 1.3 通过阿里云百炼平台获取相关的大模型
# 举例

# %%
from langchain_community.chat_models import ChatTongyi
from dotenv import load_dotenv

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")

# 2、模型的初始化
llm_tongyi = ChatTongyi(
    model="qwen3-max",
    # api_key=DASHSCOPE_API_KEY,
)

# 3、模型的调用
response= llm_tongyi.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是通义千问，阿里巴巴集团旗下的超大规模语言模型，能够回答问题、创作文字、编程等，致力于为用户提供高效、智能的服务。' additional_kwargs={} response_metadata={'model_name': 'qwen3-max', 'finish_reason': 'stop', 'request_id': 'a5812036-afb9-9021-961b-5b7b4e55aa28', 'token_usage': {'input_tokens': 13, 'output_tokens': 32, 'prompt_tokens_details': {'cached_tokens': 0}, 'total_tokens': 45}} id='lc_run--01a0d7ca-6808-7ab2-9d03-90942f40312e-0' tool_calls=[] invalid_tool_calls=[]

# %% [markdown]
# # 2. 兼容的写法
# 使用ChatOpenAI
#
# 举例1：调用deepseek官网提供的大模型

# %%
from langchain_openai import ChatOpenAI

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

print(model.invoke("1 + 1 = ？"))
# Out:
# content='2' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 37, 'total_tokens': 83, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 44, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 37}, 'model_provider': 'openai', 'model_name': 'deepseek-flash', 'system_fingerprint': 'aeb56401ca74e127821c4f9126dcb669', 'id': '7c4eef6b-3405-40a1-97f9-b69e00acf167', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d7cc-e2d3-71d0-a1b6-d49e1e5dffff-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 37, 'output_tokens': 46, 'total_tokens': 83, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 44}}

# %% [markdown]
# 举例2：调用智谱平台的大模型

# %%
from langchain_openai import ChatOpenAI

# 加载配置文件
load_dotenv(override=True)

ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
ZHPPUAI_BASE_URL = os.getenv("ZHPPUAI_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="glm-5.1",
    api_key=ZHIPUAI_API_KEY,
    base_url=ZHPPUAI_BASE_URL,
)

print(model.invoke("1 + 1 = ？"))
# Out:
# content='2' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 141, 'prompt_tokens': 11, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 139, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'glm-5.1', 'system_fingerprint': None, 'id': '2026092517025900cd09e73cc644cd', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d7cd-ba67-7023-9109-eea89f9c0b49-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 11, 'output_tokens': 141, 'total_tokens': 152, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 139}}

# %% [markdown]
# ## 3. 使用中转平台
#
# ### 3.1 使用OpenRouter
#
# 举例1：调用的国内的大模型。比如Deepseek

# %%
from langchain_openrouter import ChatOpenRouter
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

# 获取大模型
model = ChatOpenRouter(
    model="deepseek/deepseek-v4-flash",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='我是DeepSeek，由深度求索公司创造的AI助手，致力于为你提供免费、高效、精准的文本处理服务，支持文件上传、联网搜索和百万级上下文处理。' additional_kwargs={'reasoning_content': '好的，用户让我用一句话介绍自己。这是一个非常简单的请求，核心是让用户快速了解我的身份和基本能力。\n\n我需要抓住最核心的特点：我是谁（DeepSeek），我的创造者（深度求索公司），以及最关键的能力（免费、文本处理、文件上传、联网搜索、长上下文）。用一句话把这些信息清晰、自然地串联起来，让用户一目了然。\n\n想到了用“我是DeepSeek”开头明确身份，随后用“由深度求索公司创造的AI助手”点明出处，最后用“专注文本处理”概括核心功能，并补充“支持文件上传、联网搜索和百万级上下文”作为亮点，这样既完整又简洁。', 'reasoning_details': [{'type': 'reasoning.text', 'text': '好的，用户让我用一句话介绍自己。这是一个非常简单的请求，核心是让用户快速了解我的身份和基本能力。\n\n我需要抓住最核心的特点：我是谁（DeepSeek），我的创造者（深度求索公司），以及最关键的能力（免费、文本处理、文件上传、联网搜索、长上下文）。用一句话把这些信息清晰、自然地串联起来，让用户一目了然。\n\n想到了用“我是DeepSeek”开头明确身份，随后用“由深度求索公司创造的AI助手”点明出处，最后用“专注文本处理”概括核心功能，并补充“支持文件上传、联网搜索和百万级上下文”作为亮点，这样既完整又简洁。', 'format': 'unknown', 'index': 0.0}]} response_metadata={'model_name': 'deepseek/deepseek-v4-flash', 'id': 'gen-1790327424-NQsqdIGWe55jzLxobSil', 'created': 1790327424, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter'} id='lc_run--01a0d7d2-2049-7763-aaac-5c7cd3a9f34b-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 184, 'total_tokens': 192, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 143}}

# %% [markdown]
# 举例2：调用国外的大模型。比如gpt

# %%
from langchain_openrouter import ChatOpenRouter
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

# OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
# OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

# 获取大模型
model = ChatOpenRouter(
    model="openai/gpt-4o-mini",
    # api_key=OPENROUTER_API_KEY,
    # base_url=OPENROUTER_API_BASE,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# ---------------------------------------------------------------------------
# OpenRouterDefaultError                    Traceback (most recent call last)
# Cell In[16], line 18
#      14     # api_key=OPENROUTER_API_KEY,
#      15     # base_url=OPENROUTER_API_BASE,
#      16 )
#      17
# ---> 18 print(model.invoke("一句话介绍下你自己"))
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/langchain_openrouter/chat_models.py:431, in ChatOpenRouter._generate(self, messages, stop, run_manager, **kwargs)
#     429 _strip_internal_kwargs(params)
#     430 sdk_messages = _wrap_messages_for_sdk(message_dicts)
# --> 431 response = self.client.chat.send(messages=sdk_messages, **params)
#     432 return self._create_chat_result(response)
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/openrouter/chat.py:637, in Chat.send(self, messages, http_referer, x_title, provider, plugins, user, session_id, trace, model, models, frequency_penalty, logit_bias, logprobs, top_logprobs, max_completion_tokens, max_tokens, metadata, presence_penalty, reasoning, response_format, seed, stop, stream, stream_options, temperature, parallel_tool_calls, tool_choice, tools, top_p, debug, image_config, modalities, retries, server_url, timeout_ms, http_headers)
#     635 if utils.match_response(http_res, "4XX", "*"):
#     636     http_res_text = utils.stream_to_text(http_res)
# --> 637     raise errors.OpenRouterDefaultError(
#     638         "API error occurred", http_res, http_res_text
#     639     )
#     640 if utils.match_response(http_res, "5XX", "*"):
#     641     http_res_text = utils.stream_to_text(http_res)
#
# OpenRouterDefaultError: API error occurred: Status 403. Body: {"error":{"message":"This model is not available in your region.","code":403,"metadata":{"routing_funnel":[{"step":"Initial Endpoints","endpoint_count":3},{"step":"Filter by Regional Surcharge","endpoint_count":2}],"failed_routing_step":"Gate Endpoints with Geo Restrictions"}}}

# %% [markdown]
# ### 3.2 使用CloseAI平台
#
# 举例1：调用国内的大模型。比如deepseek

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[17], line 18
#      14     api_key=CLOSEAI_API_KEY,
#      15     base_url=CLOSEAI_BASE_URL,
#      16 )
#      17
# ---> 18 print(model.invoke("一句话介绍下你自己"))
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/langchain_openai/chat_models/base.py:1492, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1490     _handle_openai_bad_request(e)
#    1491 except openai.APIError as e:
# -> 1492     _handle_openai_api_error(e)
#    1493 except Exception as e:
#    1494     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/langchain_openai/chat_models/base.py:1487, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1480         return _construct_lc_result_from_responses_api(
#    1481             response,
#    1482             schema=original_schema_obj,
#    1483             metadata=generation_info,
#    1484             output_version=self.output_version,
#    1485         )
#    1486     else:
# -> 1487         raw_response = self.client.with_raw_response.create(**payload)
#    1488         response = raw_response.parse()
#    1489 except openai.BadRequestError as e:
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/openai/_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/openai/resources/chat/completions/completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1164 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1165 def create(
#    1166     self,
#    (...)   1208     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1209 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1210     validate_response_format(response_format)
# -> 1211     return self._post(
#    1212         "/chat/completions",
#    1213         body=maybe_transform(
#    1214             {
#    1215                 "messages": messages,
#    1216                 "model": model,
#    1217                 "audio": audio,
#    1218                 "frequency_penalty": frequency_penalty,
#    1219                 "function_call": function_call,
#    1220                 "functions": functions,
#    1221                 "logit_bias": logit_bias,
#    1222                 "logprobs": logprobs,
#    1223                 "max_completion_tokens": max_completion_tokens,
#    1224                 "max_tokens": max_tokens,
#    1225                 "metadata": metadata,
#    1226                 "modalities": modalities,
#    1227                 "n": n,
#    1228                 "parallel_tool_calls": parallel_tool_calls,
#    1229                 "prediction": prediction,
#    1230                 "presence_penalty": presence_penalty,
#    1231                 "prompt_cache_key": prompt_cache_key,
#    1232                 "prompt_cache_retention": prompt_cache_retention,
#    1233                 "reasoning_effort": reasoning_effort,
#    1234                 "response_format": response_format,
#    1235                 "safety_identifier": safety_identifier,
#    1236                 "seed": seed,
#    1237                 "service_tier": service_tier,
#    1238                 "stop": stop,
#    1239                 "store": store,
#    1240                 "stream": stream,
#    1241                 "stream_options": stream_options,
#    1242                 "temperature": temperature,
#    1243                 "tool_choice": tool_choice,
#    1244                 "tools": tools,
#    1245                 "top_logprobs": top_logprobs,
#    1246                 "top_p": top_p,
#    1247                 "user": user,
#    1248                 "verbosity": verbosity,
#    1249                 "web_search_options": web_search_options,
#    1250             },
#    1251             completion_create_params.CompletionCreateParamsStreaming
#    1252             if stream
#    1253             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254         ),
#    1255         options=make_request_options(
#    1256             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257         ),
#    1258         cast_to=ChatCompletion,
#    1259         stream=stream or False,
#    1260         stream_cls=Stream[ChatCompletionChunk],
#    1261     )
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/openai/_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.14/site-packages/openai/_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# PermissionDeniedError: Error code: 403 - {'error': {'code': 'insufficient_balance', 'message': '余额不足，请充值后再使用'}}

# %% [markdown]
# 举例2：调用国外的大模型。比如：gpt

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="gpt-5.4-mini",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))

# %% [markdown]
# ## 4. 使用LangChain1.x的统一方式
#
# 使用 init_chat_model()
#
# 举例1：调用DeepSeek官网的DeepSeek模型

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model = init_chat_model(
    # model="deepseek-v4-flash",
    # model_provider="deepseek",
    # 或者
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))

# %% [markdown]
# 举例2：调用CloseAI平台的大模型

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="openai:deepseek-v4-flash",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))

# %% [markdown]
# 举例3：

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="openai:gpt-5.4-mini",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))

# %% [markdown]
# ## 5. 小结
#
# DeepSeek官网的DeepSeek模型：ChatDeepSeek() 、 ChatOpenAI() 、 init_chat_model()
#
# 阿里云百炼平台的DeepSeek模型：ChatTongyi() 、ChatOpenAI() 、 init_chat_model()
#
# OpenRouter平台的DeepSeek模型：ChatOpenRouter() 、 ChatOpenAI()、init_chat_model()
#
# CloseAI平台的DeepSeek模型：ChatOpenAI()、init_chat_model()
